# %%
import pandas as pd

# %%
df=pd.read_csv("project_files/kenya_listings.csv")

# %%
df.sub_type.value_counts()
# Out:
# Townhouse                               1563
# Office Space                             872
# Residential Land                         810
# Detached Duplex                          630
# Detached Bungalow                        579
# Mixed-use Land                           376
# Semi-detached Bungalow                   286
# Mini Flat                                244
# Commercial Land                          205
# Bedsitter (Single Room)                  191
# Warehouse                                186
# Semi-detached Duplex                      74
# Terraced Duplex                           55
# Shop                                      45
# Plaza / Complex / Mall                    45
# Block of Flats                            30
# Terraced Bungalow                         29
# Hotel / Guest House                       27
# Restaurant / Bar                          24
# Industrial Land                           14
# School                                     5
# Factory                                    3
# Filling Station                            3
# Tank Farm                                  2
# Conference / Meeting / Training Room       1
# Hostel                                     1
# Name: sub_type, dtype: int64

# %%
df=pd.read_csv("project_files/cleaned_listings.csv")

df=df.loc[(df['category']=='For Rent')]
print(df.price.describe())
# Out:
# count      3477.000000
# mean     119738.238999
# std       99188.367036
# min        4500.000000
# 25%       35000.000000
# 50%       95000.000000
# 75%      175000.000000
# max      400000.000000
# Name: price, dtype: float64

# %%
df.sort_values(by='price',ascending=False).head()
# Out:
#         id     price  bedrooms  bathrooms  toilets  furnished  serviced  \
# 1471  8618  400000.0         4          4      4.0          0         0
# 602   2166  400000.0         5          5      0.0          0         0
# 1635  9197  400000.0         6          6      0.0          0         0
# 951   5932  400000.0         6          7      0.0          0         0
# 55      86  400000.0         4          4      0.0          0         0
#
#       shared  parking  category   type           sub_type    state   locality  \
# 1471       0        6  For Rent  House  Detached Bungalow  Nairobi  Westlands
# 602        0        2  For Rent  House            Missing  Nairobi  Westlands
# 1635       0        0  For Rent  House            Missing  Nairobi      Karen
# 951        0        0  For Rent  House          Townhouse  Nairobi   Kitisuru
# 55         0        0  For Rent  House          Townhouse   Kiambu     Kabete
#
#                  listdate
# 1471  2021-05-18 14:45:10
# 602   2020-07-23 00:00:00
# 1635  2021-07-23 16:49:13
# 951   2020-08-17 16:15:36
# 55    2020-07-18 00:00:00

# %%
import seaborn as sns
sns.violinplot(x= 'bathrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bathrooms'>

# %%
df = df[df.bathrooms <= 8]
sns.violinplot(x= 'bathrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bathrooms'>

# %%
sns.violinplot(x= 'toilets', data=df)
# Out:
# <AxesSubplot:xlabel='toilets'>

# %%
df = df[df.toilets <= 10]
sns.violinplot(x= 'bathrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bathrooms'>

# %%
sns.violinplot(x= 'bedrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms'>

# %%
df = df[df.bedrooms <= 10]
sns.violinplot(x= 'bedrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms'>

# %%
sns.violinplot(x= 'parking', data=df)
# Out:
# <AxesSubplot:xlabel='parking'>

# %%
df = df[df.parking <= 6]
sns.violinplot(x= 'parking', data=df)
# Out:
# <AxesSubplot:xlabel='parking'>

# %%
sns.violinplot(x= 'price', data=df)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
df = df[df.price <= 400000]
sns.violinplot(x= 'price', data=df)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
# Save cleaned dataframe to new file
df.to_csv('project_files/cleaned_listings.csv', index=None)
