# %% [markdown]
# <h1>Feature Engineering</h1>
# <hr>

# %%
# import libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
#import dataset
df=pd.read_csv("project_files/cleaned_listings.csv")

# %% [markdown]
# <h1>Co-relations in the dataset</h1>

# %%
correlations = df.loc[:, ~df.columns.isin(['id'])].corr()

# %%
mask = np.zeros_like(correlations, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# %%
plt.figure(figsize=(10,10))
sns.set_style('white')
sns.heatmap(correlations*100, annot=True, fmt ='.0f', mask=mask)

# %%
correlations = df.loc[(df['category']=='For Sale')].loc[:, ~df.columns.isin(['id'])].corr()

# %%
#correlation in properties listed for sale
plt.figure(figsize=(10,10))
sns.set_style('white')
sns.heatmap(correlations*100, annot=True, fmt ='.0f', mask=mask)

# %%
correlations = df.loc[(df['category']=='For Rent')].loc[:, ~df.columns.isin(['id'])].corr()

# %%
#correlation in properties listed for sale
plt.figure(figsize=(10,10))
sns.set_style('white')
sns.heatmap(correlations*100, annot=True, fmt ='.0f', mask=mask)

# %%
df.shape
# Out:
# (9088, 17)

# %%
#create a value for pre covid years
# df2['pre_covid']=df[(df['listdate'] < '2020-3-12') ].astype(int)
df['pre_covid']=( (df.listdate <= "2020-3-12")).astype(int)

# %%
df.sort_values(by='pre_covid').head(3)
# Out:
#          id      price price_qualifier  bedrooms  bathrooms  toilets  \
# 4543  15649    17000.0       per month         2          2      0.0
# 6582   8887  7500000.0         Missing         3          2      2.0
# 6581   8886  8500000.0         Missing         3          2      2.0
#
#       furnished  serviced  shared  parking  category       type sub_type  \
# 4543          0         0       0        0  For Rent      House  Missing
# 6582          0         0       0        2  For Sale  Apartment  Missing
# 6581          0         0       0        2  For Sale  Apartment  Missing
#
#         state     locality             listdate  pre_covid
# 4543  Nairobi  Kahawa West  2022-05-25 17:10:19          0
# 6582  Nairobi       Riruta  2021-06-25 16:47:13          0
# 6581  Nairobi  Kahawa West  2021-06-25 16:35:44          0
