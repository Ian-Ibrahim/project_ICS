# %%
import pandas as pd

# %%
df=pd.read_csv("project_files/cleaned_listings.csv")

df=df.loc[(df['category']=='For Rent')]
print(df.price.describe())
# Out:
# Ngong            69
# Ongata Rongai    48
# Kitengela        42
# Name: locality, dtype: int64
# count      3477.000000
# mean     119738.238999
# std       99188.367036
# min        4500.000000
# 25%       35000.000000
# 50%       95000.000000
# 75%      175000.000000
# max      400000.000000
# Name: price, dtype: float64

# %%
df.sort_values(by='price',ascending=False).head()
# Out:
#          id     price  bedrooms  bathrooms  toilets  furnished  serviced  \
# 2989  13959  650000.0        10         10     10.0          0         0
# 518    1118  650000.0         6          7      0.0          0         0
# 979    5903  650000.0         4          3      0.0          0         0
# 3168  14736  650000.0        10         10     10.0          0         0
# 624    2300  600000.0         8          8      0.0          0         0
#
#       shared  parking  category   type         sub_type    state   locality  \
# 2989       0        0  For Rent  House        Townhouse  Nairobi      Karen
# 518        0        0  For Rent  House  Detached Duplex  Nairobi  Lavington
# 979        0        0  For Rent  House        Townhouse  Nairobi   Kilimani
# 3168       0        0  For Rent  House        Townhouse  Nairobi      Karen
# 624        0        0  For Rent  House          Missing  Nairobi  Westlands
#
#                  listdate
# 2989  2022-02-26 21:55:04
# 518   2020-07-21 00:00:00
# 979   2020-08-17 15:16:38
# 3168  2022-03-26 16:28:39
# 624   2020-07-24 00:00:00

# %%
import seaborn as sns
sns.violinplot(x= 'bathrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bathrooms'>

# %%
df = df[df.bathrooms <= 8]
sns.violinplot(x= 'bathrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bathrooms'>

# %%
sns.violinplot(x= 'toilets', data=df)
# Out:
# <AxesSubplot:xlabel='toilets'>

# %%
df = df[df.toilets <= 10]
sns.violinplot(x= 'bathrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bathrooms'>

# %%
sns.violinplot(x= 'bedrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms'>

# %%
df = df[df.bedrooms <= 10]
sns.violinplot(x= 'bedrooms', data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms'>

# %%
sns.violinplot(x= 'parking', data=df)
# Out:
# <AxesSubplot:xlabel='parking'>

# %%
df = df[df.parking <= 6]
sns.violinplot(x= 'parking', data=df)
# Out:
# <AxesSubplot:xlabel='parking'>

# %%
sns.violinplot(x= 'price', data=df)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
df = df[df.price <= 400000]
sns.violinplot(x= 'price', data=df)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
# Save cleaned dataframe to new file
df.to_csv('project_files/cleaned_listings.csv', index=None)
