# %% [markdown]
# <h1>Data cleaning</h1>
# <p>In this module we will:</p>
# <ul>
#     <li>Remove unwanted outliers</li>
#     <li>Remove unwanted observations</li>
#     <li>Label missing categorical data</li>
#     <li>Drop unwanted outliers</li>
#     <li>Flag and fill missing numerical data</li>
# </ul>

# %%
# import libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
#import dataset
df=pd.read_csv("project_files/kenya_listings.csv")

# %% [markdown]
# <h2>Flag and fill missing numerical data</h2>
# <p>Checking null/missing values in the dataset</p>

# %%
#df.select_dtypes(exclude=['object']).isnull().sum()
count=df.isna().sum()
percent=((count/df.shape[0])*100)
null=pd.DataFrame(pd.concat([count,percent],keys=['Missing values','% Missing values'],axis=1))
null
# Out:
#                  Missing values  % Missing values
# id                            0          0.000000
# price                         3          0.018614
# price_qualifier            8870         55.035056
# bedrooms                      0          0.000000
# bathrooms                     0          0.000000
# toilets                   10028         62.220016
# furnished                     0          0.000000
# serviced                      0          0.000000
# shared                        0          0.000000
# parking                       0          0.000000
# category                      0          0.000000
# type                          0          0.000000
# sub_type                   9817         60.910839
# state                         0          0.000000
# locality                      6          0.037228
# sub_locality              15071         93.509958
# listdate                      0          0.000000

# %%
# Missing toilet values should be 0
df['toilets'] = df['toilets'].fillna(0)

# %%
df['price'] = df['price'].fillna(0)

# %% [markdown]
# <h2>Fixing structural errors</h2>

# %%
df.price_qualifier.value_counts()
# Out:
# per month                       6227
# per calendar month               373
# per plot                         228
# per acre                         128
# per square foot / per month      112
# per day                           62
# per square meter / per month      55
# per square foot / per week        46
# per hectare                        6
# per square meter / per week        5
# per square foot / per annum        3
# per square meter                   1
# per square foot                    1
# Name: price_qualifier, dtype: int64

# %%
df.type.value_counts()
# Out:
# House                   6026
# Apartment               5840
# Land                    2669
# Commercial Property     1580
# Event Centre / Venue       2
# Name: type, dtype: int64

# %%
df.sub_type.value_counts()
# Out:
# Townhouse                               1563
# Office Space                             872
# Residential Land                         810
# Detached Duplex                          630
# Detached Bungalow                        579
# Mixed-use Land                           376
# Semi-detached Bungalow                   286
# Mini Flat                                244
# Commercial Land                          205
# Bedsitter (Single Room)                  191
# Warehouse                                186
# Semi-detached Duplex                      74
# Terraced Duplex                           55
# Plaza / Complex / Mall                    45
# Shop                                      45
# Block of Flats                            30
# Terraced Bungalow                         29
# Hotel / Guest House                       27
# Restaurant / Bar                          24
# Industrial Land                           14
# School                                     5
# Factory                                    3
# Filling Station                            3
# Tank Farm                                  2
# Hostel                                     1
# Conference / Meeting / Training Room       1
# Name: sub_type, dtype: int64

# %%
df.state.value_counts()
# Out:
# Nairobi          8935
# Kiambu           2694
# Kajiado          1294
# Mombasa          1125
# Machakos          534
# Kilifi            480
# Nakuru            290
# Kisumu            150
# Laikipia           97
# Kwale              78
# Embu               44
# Uasin Gishu        43
# Meru               42
# Nyeri              39
# Nandi              38
# Makueni            30
# Baringo            28
# Muranga            27
# Bungoma            21
# Kirinyaga          17
# Kitui              13
# Nyandarua          12
# Kericho            11
# Trans Nzoia        10
# Kakamega           10
# Kisii               9
# Isiolo              7
# Lamu                6
# Busia               6
# Narok               4
# Homa Bay            3
# Tharaka-Nithi       3
# Bomet               3
# Garissa             2
# Siaya               2
# Migori              2
# Vihiga              2
# Samburu             2
# Turkana             1
# Marsabit            1
# West Pokot          1
# Taita Taveta        1
# Name: state, dtype: int64

# %%
df.locality.value_counts()
# Out:
# Westlands          2446
# Kilimani           1199
# Kikuyu             1064
# Lavington           891
# Karen               750
#                    ...
# Akirang'Ondu          1
# Chania                1
# Gatitu/Muruguru       1
# Esise                 1
# Kiganjo/Mathari       1
# Name: locality, Length: 357, dtype: int64

# %%
df.sub_locality.value_counts()
# Out:
# Runda              553
# Loresho            107
# South C             83
# Industrial Area     80
# Thigio              34
# Muthaiga North      23
# Old Muthaiga        22
# Chiromo             20
# South B             19
# Rimpa               18
# Tassia              13
# Yukos               11
# Imara Daima         10
# Githurai 44         10
# Rosslyn              9
# Clay City            8
# Githurai 45          5
# Umoja Phase 1        5
# Lucky Summer         4
# New Muthaiga         3
# Umoja Phase 2        3
# Mukuru Village       1
# Kiembeni             1
# Kariba               1
# Kihingo              1
# Kwa Njenga           1
# Lindi                1
# Name: sub_locality, dtype: int64

# %%
df.category.value_counts()
# Out:
# For Sale         9108
# For Rent         6916
# Short Let          84
# Joint Venture       9
# Name: category, dtype: int64

# %% [markdown]
# <h3>No structural errors were noted.</h3>

# %% [markdown]
# <h2>Labelling missing categorical features</h2>

# %%
df.select_dtypes(include=['object']).isnull().sum()
# Out:
# price_qualifier     8870
# category               0
# type                   0
# sub_type            9817
# state                  0
# locality               6
# sub_locality       15071
# listdate               0
# dtype: int64

# %%
for column in df.select_dtypes(include=['object']).columns.tolist():
    df[column] = df[column].fillna('Missing')

# %%
df.select_dtypes(include=['object']).isnull().sum()
# Out:
# price_qualifier    0
# category           0
# type               0
# sub_type           0
# state              0
# locality           0
# sub_locality       0
# listdate           0
# dtype: int64

# %% [markdown]
# <h2>Dropping unwanted observations</h2>

# %%
#removing duplicates in the dataset
df=df.drop_duplicates()
df.shape
# Out:
# (16117, 17)

# %% [markdown]
# <p>
#     There are some properties that will be removed in the dataset which includes:
#     <ul>
#         <li>Property types-land,commercial property,event centers </li>
#     </ul>
# </p>

# %%
df=df.loc[(df['type']=='House')| (df['type']=='Apartment')]

# %%
df.price_qualifier.value_counts()
# Out:
# Missing               6251
# per month             5184
# per calendar month     370
# per day                 61
# Name: price_qualifier, dtype: int64

# %%
df.price_qualifier.value_counts()
# Out:
# Missing               6251
# per month             5184
# per calendar month     370
# per day                 61
# Name: price_qualifier, dtype: int64

# %%
df.loc[(df['price_qualifier']=='per day')].sort_values(by='price' ,ascending=False).head(30)
# Out:
#           id    price price_qualifier  bedrooms  bathrooms  toilets  \
# 15894  15902  40000.0         per day         4          4      5.0
# 6315    6316  30000.0         per day         4          0      0.0
# 4345    4346  25000.0         per day         4          0      0.0
# 8812    8813  25000.0         per day         4          4      5.0
# 11827  11831  18000.0         per day         5          5      5.0
# 15886  15894  18000.0         per day         3         32      4.0
# 15862  15870  18000.0         per day         4          4      4.0
# 14952  14960  17000.0         per day         3          3      4.0
# 15893  15901  15000.0         per day         3          3      4.0
# 15891  15899  15000.0         per day         4          3      4.0
# 15741  15749  15000.0         per day         3          3      3.0
# 14404  14412  15000.0         per day         3          3      3.0
# 12485  12493  15000.0         per day         4          5      5.0
# 12479  12487  15000.0         per day         5          5      5.0
# 12196  12204  15000.0         per day         4          3      3.0
# 15923  15931  15000.0         per day         5          0      5.0
# 7349    7350  15000.0         per day         2          0      0.0
# 9228    9229  15000.0         per day         3          3      3.0
# 15858  15866  14000.0         per day         3          3      4.0
# 9735    9736  13000.0         per day         3          3      3.0
# 11659  11663  12000.0         per day         3          3      3.0
# 11828  11832  12000.0         per day         3          3      4.0
# 15860  15868  12000.0         per day         3          2      2.0
# 14229  14237  12000.0         per day         3          2      3.0
# 15889  15897  12000.0         per day         2          1      1.0
# 14000  14008  12000.0         per day         3          2      3.0
# 9336    9337  10500.0         per day         2          2      2.0
# 9736    9737  10000.0         per day         2          2      2.0
# 10781  10782  10000.0         per day         2          2      2.0
# 13943  13951  10000.0         per day         3          3      4.0
#
#        furnished  serviced  shared  parking   category       type  \
# 15894          1         0       0        2  Short Let      House
# 6315           0         0       0        0  Short Let      House
# 4345           0         0       0        0  Short Let      House
# 8812           1         0       0        2  Short Let      House
# 11827          0         0       1        4  Short Let      House
# 15886          1         0       0        2  Short Let  Apartment
# 15862          1         0       0        3  Short Let      House
# 14952          1         1       0        2  Short Let  Apartment
# 15893          1         0       0        2  Short Let  Apartment
# 15891          1         0       0        2  Short Let      House
# 15741          1         0       0        5  Short Let  Apartment
# 14404          1         1       0        2  Short Let  Apartment
# 12485          1         0       0        2  Short Let  Apartment
# 12479          1         0       0        2  Short Let  Apartment
# 12196          1         0       0        1  Short Let  Apartment
# 15923          0         0       0        0  Short Let      House
# 7349           0         0       0        0  Short Let  Apartment
# 9228           1         1       0        2  Short Let  Apartment
# 15858          1         0       0        2  Short Let  Apartment
# 9735           1         1       0        2  Short Let  Apartment
# 11659          1         1       0        2  Short Let  Apartment
# 11828          1         1       0        2  Short Let  Apartment
# 15860          1         0       0        2  Short Let  Apartment
# 14229          1         1       0        2  Short Let  Apartment
# 15889          1         0       0        2  Short Let  Apartment
# 14000          1         1       0        2  Short Let  Apartment
# 9336           0         0       0        2  Short Let  Apartment
# 9736           1         1       1        2  Short Let  Apartment
# 10781          1         1       0        4  Short Let      House
# 13943          1         1       0        2  Short Let      House
#
#                    sub_type    state      locality sub_locality  \
# 15894     Terraced Bungalow   Kilifi  Malindi Town      Missing
# 6315                Missing  Makueni  Emali/Mulala      Missing
# 4345        Detached Duplex   Kilifi  Malindi Town      Missing
# 8812              Townhouse  Mombasa        Shanzu      Missing
# 11827               Missing  Mombasa         Nyali      Missing
# 15886               Missing  Mombasa         Nyali      Missing
# 15862             Townhouse   Kilifi        Watamu      Missing
# 14952               Missing  Mombasa         Nyali      Missing
# 15893               Missing  Mombasa        Shanzu      Missing
# 15891     Detached Bungalow   Kilifi  Malindi Town      Missing
# 15741               Missing  Mombasa       Bamburi      Missing
# 14404               Missing  Mombasa       Bamburi      Missing
# 12485               Missing  Mombasa         Nyali      Missing
# 12479               Missing  Mombasa         Nyali      Missing
# 12196               Missing  Mombasa         Nyali      Missing
# 15923               Missing   Kilifi        Mtwapa      Missing
# 7349                Missing  Nairobi     Lavington      Missing
# 9228                Missing  Mombasa         Nyali      Missing
# 15858               Missing  Mombasa         Nyali      Missing
# 9735                Missing  Mombasa         Nyali      Missing
# 11659               Missing  Mombasa         Nyali      Missing
# 11828               Missing  Mombasa         Nyali      Missing
# 15860               Missing  Mombasa        Shanzu      Missing
# 14229               Missing  Mombasa         Nyali      Missing
# 15889               Missing   Kilifi        Watamu      Missing
# 14000               Missing  Mombasa         Nyali      Missing
# 9336                Missing  Mombasa       Bamburi      Missing
# 9736                Missing  Mombasa         Nyali      Missing
# 10781  Semi-detached Duplex    Kwale        Ukunda      Missing
# 13943               Missing  Mombasa         Nyali      Missing
#
#                   listdate
# 15894  2022-06-06 21:49:48
# 6315   2020-08-22 23:50:39
# 4345   2020-08-01 23:40:42
# 8812   2021-06-22 08:42:02
# 11827  2021-12-15 17:48:00
# 15886  2022-06-06 20:03:52
# 15862  2022-06-06 09:34:15
# 14952  2022-04-08 13:38:23
# 15893  2022-06-06 21:34:15
# 15891  2022-06-06 21:24:29
# 15741  2022-05-31 15:59:09
# 14404  2022-03-10 12:55:59
# 12485  2022-01-12 15:31:18
# 12479  2022-01-12 15:11:50
# 12196  2022-01-07 14:21:33
# 15923  2022-06-07 14:12:24
# 7349   2020-08-26 07:01:53
# 9228   2021-07-28 00:51:33
# 15858  2022-06-06 01:52:16
# 9735   2021-09-08 19:35:19
# 11659  2021-12-07 16:42:42
# 11828  2021-12-15 17:54:52
# 15860  2022-06-06 09:05:15
# 14229  2022-03-07 11:27:55
# 15889  2022-06-06 20:36:13
# 14000  2022-02-28 17:56:26
# 9336   2021-08-09 00:04:04
# 9736   2021-09-08 19:41:49
# 10781  2021-11-02 13:57:07
# 13943  2022-02-26 17:40:41

# %%
df.state.value_counts()
# Out:
# Nairobi          7332
# Kiambu           1552
# Kajiado           882
# Mombasa           881
# Machakos          354
# Kilifi            246
# Nakuru            155
# Kisumu            111
# Uasin Gishu        37
# Laikipia           35
# Kwale              33
# Nandi              31
# Embu               29
# Meru               27
# Baringo            23
# Nyeri              19
# Muranga            17
# Makueni            15
# Kitui              10
# Bungoma            10
# Kirinyaga           9
# Trans Nzoia         8
# Kakamega            7
# Isiolo              7
# Kericho             7
# Kisii               6
# Bomet               3
# Busia               3
# Nyandarua           3
# Homa Bay            2
# Tharaka-Nithi       2
# Lamu                2
# Garissa             1
# Turkana             1
# Narok               1
# Migori              1
# Samburu             1
# Marsabit            1
# Vihiga              1
# West Pokot          1
# Name: state, dtype: int64

# %%
df.shape
# Out:
# (11866, 17)

# %%
df.loc[(df['locality']=='Missing')].head(10)
# Out:
#         id      price price_qualifier  bedrooms  bathrooms  toilets  \
# 1805  1806  8500000.0         Missing         0          0      0.0
# 2949  2950   160000.0       per month         4          4      0.0
# 2953  2954   150000.0       per month         4          4      0.0
# 2961  2962   150000.0       per month         4          4      0.0
#
#       furnished  serviced  shared  parking  category       type sub_type  \
# 1805          0         0       0        0  For Sale  Apartment  Missing
# 2949          0         0       0        0  For Rent  Apartment  Missing
# 2953          0         0       0        0  For Rent  Apartment  Missing
# 2961          0         0       0        0  For Rent  Apartment  Missing
#
#         state locality sub_locality             listdate
# 1805  Nairobi  Missing      Missing  2020-07-22 00:00:00
# 2949  Nairobi  Missing      Missing  2020-07-25 16:53:16
# 2953  Nairobi  Missing      Missing  2020-07-25 16:57:55
# 2961  Nairobi  Missing      Missing  2020-07-25 17:17:15

# %%
df.loc[(df['sub_type']=='Bedsitter (Single Room)')& (df['bedrooms']==0)].shape
# Out:
# (186, 17)

# %%
df.loc[(df['category']=='For Rent')& (df['price_qualifier']=='Missing')].head()
# Out:
#       id     price price_qualifier  bedrooms  bathrooms  toilets  furnished  \
# 12    13  270000.0         Missing         4          4      4.0          0
# 36    37  225000.0         Missing         4          4      4.0          0
# 37    38  110000.0         Missing         2          2      2.0          0
# 553  554    7000.0         Missing         2          2      0.0          0
# 555  556   84000.0         Missing         1          1      0.0          1
#
#      serviced  shared  parking  category       type   sub_type    state  \
# 12          0       0        0  For Rent      House  Townhouse  Nairobi
# 36          0       0        0  For Rent  Apartment    Missing  Nairobi
# 37          0       0        0  For Rent  Apartment    Missing  Nairobi
# 553         0       0        0  For Rent  Apartment    Missing  Nairobi
# 555         0       0        0  For Rent  Apartment    Missing  Nairobi
#
#        locality sub_locality             listdate
# 12    Lavington      Missing  2020-07-18 00:00:00
# 36    Westlands      Missing  2020-07-18 00:00:00
# 37    Westlands      Missing  2020-07-18 00:00:00
# 553  Kileleshwa      Missing  2020-07-19 00:00:00
# 555   Westlands      Missing  2020-07-19 00:00:00

# %%
df.loc[(df['type']=='Apartment')].sub_type.value_counts()
# Out:
# Missing                    5405
# Mini Flat                   243
# Bedsitter (Single Room)     191
# Detached Duplex               1
# Name: sub_type, dtype: int64

# %%
df.sub_type.value_counts()
# Out:
# Missing                    8186
# Townhouse                  1563
# Detached Duplex             630
# Detached Bungalow           579
# Semi-detached Bungalow      286
# Mini Flat                   243
# Bedsitter (Single Room)     191
# Semi-detached Duplex         74
# Terraced Duplex              55
# Block of Flats               30
# Terraced Bungalow            29
# Name: sub_type, dtype: int64
